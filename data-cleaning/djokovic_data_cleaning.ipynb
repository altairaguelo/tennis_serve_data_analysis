# %%
import pandas as pd
import numpy as np

# %%
djo = pd.read_csv('djokovic_serve_chart.csv')
#djo.drop(columns=['Unnamed: 0'], inplace=True)
djo = djo.replace('-', np.nan)

# %%
djo
# Out:
#      year          tourney round result  opponent Unret% <=3 W% RiP W%  \
# 0    2025           Madrid   R64      L   Arnaldi  28.3%  35.8%  48.6%
# 1    2025      Monte Carlo   R32      L    Tabilo  14.3%  23.2%  50.0%
# 2    2025            Miami     F      L    Mensik  28.4%  41.9%  59.6%
# 3    2025            Miami    SF      W  Dimitrov  33.3%  44.4%  62.1%
# 4    2025            Miami    QF      W     Korda  47.5%  59.3%  61.3%
# ..    ...              ...   ...    ...       ...    ...    ...    ...
# 593  2006    Roland Garros    QF      L     Nadal   7.7%  21.5%  49.0%
# 594  2006      Monte Carlo   R64      L   Federer  14.9%  28.7%  53.9%
# 595  2006            Miami   R64      L     Coria  17.1%  28.0%  40.3%
# 596  2005          US Open  R128      W   Monfils  19.0%  34.6%  54.3%
# 597  2005  Australian Open  R128      L     Safin   9.1%  12.1%  27.3%
#
#     RiP W%.1 SvImpact  ... RiP W%.2 RiP W%.3 SvImpact1st D Wide% A Wide%  \
# 0      50.0%    33.4%  ...    48.6%    50.0%       53.6%   38.5%   45.0%
# 1      56.5%    19.8%  ...    50.0%    56.5%       33.7%   56.3%   42.9%
# 2      64.9%    35.9%  ...    59.6%    64.9%       43.9%   57.7%   66.7%
# 3      68.0%    38.9%  ...    62.1%    68.0%       42.3%   42.1%   45.0%
# 4      65.2%    55.4%  ...    61.3%    65.2%       62.7%   42.9%   57.1%
# ..       ...      ...  ...      ...      ...         ...     ...     ...
# 593    54.1%    17.5%  ...    49.0%    54.1%       27.1%   50.0%   27.3%
# 594    51.9%    23.0%  ...    53.9%    51.9%       26.0%   40.0%   65.7%
# 595    44.4%    23.0%  ...    40.3%    44.4%       30.9%   30.8%   68.4%
# 596    59.6%    30.1%  ...    54.3%    59.6%       37.6%   37.3%   41.2%
# 597    30.3%    11.5%  ...    27.3%    30.3%       19.5%   35.0%   52.6%
#
#     BP Wide% 2nd: Unret% 2nd: <=3 W% 2nd: RiP W% 2ndAgg
# 0      50.0%        0.0%        5.9%       47.1%   -118
# 1      25.0%        4.2%        4.2%       43.5%    -76
# 2       0.0%       11.8%       11.8%       46.7%      4
# 3       0.0%       20.0%       20.0%       25.0%     65
# 4        NaN       20.0%       20.0%       50.0%    -79
# ..       ...         ...         ...         ...    ...
# 593     0.0%        0.0%        8.3%       33.3%   -118
# 594   100.0%       20.0%       36.7%       58.3%     76
# 595    75.0%       16.1%       29.0%       34.6%     31
# 596   100.0%       16.4%       23.6%       43.5%     47
# 597    75.0%        0.0%        0.0%       22.7%   -118
#
# [598 rows x 22 columns]

# %%
djo.dtypes
# Out:
# year             int64
# tourney         object
# round           object
# result          object
# opponent        object
# Unret%         float64
# <=3 W%         float64
# RiP W%         float64
# RiP W%.1       float64
# SvImpact       float64
# 1st: Unret%    float64
# 1st: <=3 W%    float64
# RiP W%.2       float64
# RiP W%.3       float64
# SvImpact1st    float64
# D Wide%        float64
# A Wide%        float64
# BP Wide%       float64
# 2nd: Unret%    float64
# 2nd: <=3 W%    float64
# 2nd: RiP W%    float64
# 2ndAgg           int64
# dtype: object

# %%
string_cols=[ 'Unret%', '<=3 W%',
       'RiP W%', 'RiP W%.1', 'SvImpact', '1st: Unret%', '1st: <=3 W%',
       'RiP W%.2', 'RiP W%.3', 'SvImpact1st', 'D Wide%', 'A Wide%', 'BP Wide%',
       '2nd: Unret%', '2nd: <=3 W%', '2nd: RiP W%']

for col in string_cols:
    djo[col] = djo[col].str.replace('%', '')
    djo[col] = djo[col].astype('float64')
djo
# Out:
#      year          tourney round result  opponent  Unret%  <=3 W%  RiP W%  \
# 0    2025           Madrid   R64      L   Arnaldi    28.3    35.8    48.6
# 1    2025      Monte Carlo   R32      L    Tabilo    14.3    23.2    50.0
# 2    2025            Miami     F      L    Mensik    28.4    41.9    59.6
# 3    2025            Miami    SF      W  Dimitrov    33.3    44.4    62.1
# 4    2025            Miami    QF      W     Korda    47.5    59.3    61.3
# ..    ...              ...   ...    ...       ...     ...     ...     ...
# 593  2006    Roland Garros    QF      L     Nadal     7.7    21.5    49.0
# 594  2006      Monte Carlo   R64      L   Federer    14.9    28.7    53.9
# 595  2006            Miami   R64      L     Coria    17.1    28.0    40.3
# 596  2005          US Open  R128      W   Monfils    19.0    34.6    54.3
# 597  2005  Australian Open  R128      L     Safin     9.1    12.1    27.3
#
#      RiP W%.1  SvImpact  ...  RiP W%.2  RiP W%.3  SvImpact1st  D Wide%  \
# 0        50.0      33.4  ...      48.6      50.0         53.6     38.5
# 1        56.5      19.8  ...      50.0      56.5         33.7     56.3
# 2        64.9      35.9  ...      59.6      64.9         43.9     57.7
# 3        68.0      38.9  ...      62.1      68.0         42.3     42.1
# 4        65.2      55.4  ...      61.3      65.2         62.7     42.9
# ..        ...       ...  ...       ...       ...          ...      ...
# 593      54.1      17.5  ...      49.0      54.1         27.1     50.0
# 594      51.9      23.0  ...      53.9      51.9         26.0     40.0
# 595      44.4      23.0  ...      40.3      44.4         30.9     30.8
# 596      59.6      30.1  ...      54.3      59.6         37.6     37.3
# 597      30.3      11.5  ...      27.3      30.3         19.5     35.0
#
#      A Wide%  BP Wide%  2nd: Unret%  2nd: <=3 W%  2nd: RiP W%  2ndAgg
# 0       45.0      50.0          0.0          5.9         47.1    -118
# 1       42.9      25.0          4.2          4.2         43.5     -76
# 2       66.7       0.0         11.8         11.8         46.7       4
# 3       45.0       0.0         20.0         20.0         25.0      65
# 4       57.1       NaN         20.0         20.0         50.0     -79
# ..       ...       ...          ...          ...          ...     ...
# 593     27.3       0.0          0.0          8.3         33.3    -118
# 594     65.7     100.0         20.0         36.7         58.3      76
# 595     68.4      75.0         16.1         29.0         34.6      31
# 596     41.2     100.0         16.4         23.6         43.5      47
# 597     52.6      75.0          0.0          0.0         22.7    -118
#
# [598 rows x 22 columns]

# %%
djo['tourney'].unique()
# Out:
# array(['Madrid', 'Monte Carlo', 'Miami', 'Indian Wells', 'Doha',
#        'Australian Open', 'Brisbane', 'Shanghai', 'US Open',
#        'Paris Olympics', 'Wimbledon', 'Roland Garros', 'Geneva', 'Rome',
#        'United Cup', 'Davis Cup', 'Tour Finals', 'Paris', 'Cincinnati',
#        'Banja Luka', 'Dubai', 'Adelaide 1', 'Astana', 'Tel Aviv',
#        'Laver Cup', 'Belgrade ', 'Tokyo Olympics', 'Belgrade 2',
#        'Belgrade', 'Vienna', 'Atp Cup', 'Tokyo', 'Canada', "Queen's Club",
#        'Eastbourne', 'Acapulco', 'Rio Olympics', 'Beijing',
#        'London Olympics', 'Basel', 'Halle', 'Masters Cup', 'Bangkok',
#        'Beijing Olympics', 'Hamburg', 'Estoril', 'Adelaide', 'Metz',
#        'Amersfoort'], dtype=object)

# %%
surfaces = {'Wimbledon': 'grass',
           'Roland Garros': 'clay',
           'Doha': 'hard',
           'Australian Open': 'hard',
           'Tour Finals': 'hard',
           'Basel': 'hard',
           'Shanghai': 'hard',
           'Laver Cup': 'hard',
           'US Open': 'hard',
            'Cincinnati': 'hard',
           'Halle': 'grass',
           'Rome': 'clay',
           'Madrid': 'clay',
           'Miami': 'hard',
           'Indian Wells': 'hard',
           'Dubai': 'hard',
           'Paris': 'hard',
           'Stuttgart': 'grass',
           'Rotterdam': 'hard',
           'Canada': 'hard',
           'Monte Carlo': 'clay',
           'Brisbane': 'hard',
           'Istanbul': 'hard',
           'Davis Cup': 'hard',
           'Hamburg': 'clay',
           'London Olympics': 'grass',
           'Stockholm': 'hard',
           'Masters Cup': 'hard',
           'Beijing Olympics': 'hard',
           'Estoril': 'clay',
           'Tokyo': 'hard',
           'Bangkok': 'hard',
           'Gstaad': 'clay',
           'Vienna': 'hard',
           'Munich': 'clay',
           'Marseille': 'hard',
           'Milan': 'clay',
           'Sydney': 'hard',
           'Sydney Olympics': 'hard',
           's Hertogenbosch': 'grass',
           'Paris Olympics': 'clay',
           'Geneva': 'clay',
           'United Cup': 'hard',
           'Banja Luka': 'hard',
           'Adelaide 1': 'hard',
           'Astana': 'hard',
           'Tel Aviv': 'hard',
           'Belgrade': 'hard',
           'Tokyo Olympics': 'hard',
           'Belgrade 2': 'hard',
            'Belgrade ': 'hard',
            'Atp Cup': 'hard',
            'Queen\'s Club': 'grass',
            'Eastbourne': 'grass',
            'Acapulco': 'hard',
            'Rio Olympics': 'hard',
            'Beijing': 'hard',
            'Adelaide': 'hard',
            'Metz': 'hard',
            'Amersfoort': 'clay',}
djo['surface'] = djo['tourney'].apply(lambda x: surfaces[x])
djo
# Out:
#      year          tourney round result  opponent  Unret%  <=3 W%  RiP W%  \
# 0    2025           Madrid   R64      L   Arnaldi    28.3    35.8    48.6
# 1    2025      Monte Carlo   R32      L    Tabilo    14.3    23.2    50.0
# 2    2025            Miami     F      L    Mensik    28.4    41.9    59.6
# 3    2025            Miami    SF      W  Dimitrov    33.3    44.4    62.1
# 4    2025            Miami    QF      W     Korda    47.5    59.3    61.3
# ..    ...              ...   ...    ...       ...     ...     ...     ...
# 593  2006    Roland Garros    QF      L     Nadal     7.7    21.5    49.0
# 594  2006      Monte Carlo   R64      L   Federer    14.9    28.7    53.9
# 595  2006            Miami   R64      L     Coria    17.1    28.0    40.3
# 596  2005          US Open  R128      W   Monfils    19.0    34.6    54.3
# 597  2005  Australian Open  R128      L     Safin     9.1    12.1    27.3
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# 0        50.0      33.4  ...      50.0         53.6     38.5     45.0
# 1        56.5      19.8  ...      56.5         33.7     56.3     42.9
# 2        64.9      35.9  ...      64.9         43.9     57.7     66.7
# 3        68.0      38.9  ...      68.0         42.3     42.1     45.0
# 4        65.2      55.4  ...      65.2         62.7     42.9     57.1
# ..        ...       ...  ...       ...          ...      ...      ...
# 593      54.1      17.5  ...      54.1         27.1     50.0     27.3
# 594      51.9      23.0  ...      51.9         26.0     40.0     65.7
# 595      44.4      23.0  ...      44.4         30.9     30.8     68.4
# 596      59.6      30.1  ...      59.6         37.6     37.3     41.2
# 597      30.3      11.5  ...      30.3         19.5     35.0     52.6
#
#      BP Wide%  2nd: Unret%  2nd: <=3 W%  2nd: RiP W%  2ndAgg  surface
# 0        50.0          0.0          5.9         47.1    -118     clay
# 1        25.0          4.2          4.2         43.5     -76     clay
# 2         0.0         11.8         11.8         46.7       4     hard
# 3         0.0         20.0         20.0         25.0      65     hard
# 4         NaN         20.0         20.0         50.0     -79     hard
# ..        ...          ...          ...          ...     ...      ...
# 593       0.0          0.0          8.3         33.3    -118     clay
# 594     100.0         20.0         36.7         58.3      76     clay
# 595      75.0         16.1         29.0         34.6      31     hard
# 596     100.0         16.4         23.6         43.5      47     hard
# 597      75.0          0.0          0.0         22.7    -118     hard
#
# [598 rows x 23 columns]

# %%
djo_wpct = (djo['result'] == 'W').mean()

# %%
djo = djo.dropna()
djo.to_csv('djokovic_serve_chart.csv', index=False)

# %%
djo_speed = pd.read_csv('djokovic_serve_speed.csv')

# %%
djo_speed= djo_speed.dropna()
djo_speed
# Out:
#      year        tourney round result  opponent  avg speed  1st avg  \
# 0    2024        US Open   R32      L   Popyrin      108.0    114.9
# 1    2024        US Open   R64      W     Djere      106.0    117.9
# 2    2024        US Open  R128      W     Albot      107.5    116.6
# 3    2024      Wimbledon     F      L   Alcaraz      113.7    118.7
# 4    2024      Wimbledon    SF      W   Musetti      111.5    118.6
# ..    ...            ...   ...    ...       ...        ...      ...
# 102  2016  Roland Garros    QF      W   Berdych      103.2    110.0
# 103  2016  Roland Garros   R16      W  Bautista      101.3    107.8
# 104  2016  Roland Garros   R32      W    Bedene      105.4    111.3
# 105  2016  Roland Garros   R64      W    Darcis      103.5    110.9
# 106  2016  Roland Garros  R128      W        Lu      105.9    111.6
#
#      1st stdev  1st t avg  1st wide avg  max 1st  min 1st  2nd avg  2nd stdev  \
# 0          6.3      117.7         112.9    124.0     94.0     94.8        9.5
# 1          4.9      118.3         116.0    125.0    105.0     93.2       10.0
# 2          6.6      119.9         110.8    126.0    104.0     96.7       11.0
# 3          4.4      120.7         117.0    126.0    107.0    100.1        6.9
# 4          4.9      120.3         115.9    127.0     95.0     95.1        9.0
# ..         ...        ...           ...      ...      ...      ...        ...
# 102        5.4      114.0         107.7    118.0     85.0     92.5        9.5
# 103       11.3      112.8         101.0    120.0     65.0     82.6        7.3
# 104        9.4      114.5         108.5    120.0     78.0     86.7        9.9
# 105        7.8      114.3         106.1    123.0     83.0     88.3        6.7
# 106        5.9      113.6         109.6    119.0     85.0     91.9        9.5
#
#      2nd t avg  2nd wide avg  max 2nd  min 2nd
# 0        104.6          86.0    117.0     77.0
# 1        103.6          97.6    119.0     78.0
# 2         94.8         101.2    117.0     78.0
# 3        103.6         101.7    114.0     90.0
# 4         98.6         100.3    117.0     83.0
# ..         ...           ...      ...      ...
# 102       96.5          98.5    110.0     74.0
# 103       86.5         103.0    103.0     71.0
# 104      100.7          94.3    108.0     71.0
# 105       92.5          88.7    102.0     79.0
# 106       90.8          86.3    106.0     78.0
#
# [100 rows x 18 columns]

# %%
djo_speed.to_csv('djokovic_serve_speed.csv', index=False)

# %%
djo.isnull().sum()
# Out:
# year           0
# tourney        0
# round          0
# result         0
# opponent       0
# Unret%         0
# <=3 W%         0
# RiP W%         0
# RiP W%.1       0
# SvImpact       0
# 1st: Unret%    0
# 1st: <=3 W%    0
# RiP W%.2       0
# RiP W%.3       0
# SvImpact1st    0
# D Wide%        0
# A Wide%        0
# BP Wide%       0
# 2nd: Unret%    0
# 2nd: <=3 W%    0
# 2nd: RiP W%    0
# 2ndAgg         0
# surface        0
# dtype: int64

# %%
djo_speed.isnull().sum()
# Out:
# year            0
# tourney         0
# round           0
# result          0
# opponent        0
# avg speed       0
# 1st avg         0
# 1st stdev       0
# 1st t avg       0
# 1st wide avg    0
# max 1st         0
# min 1st         0
# 2nd avg         0
# 2nd stdev       0
# 2nd t avg       0
# 2nd wide avg    0
# max 2nd         0
# min 2nd         0
# dtype: int64

# %%
djo.shape
# Out:
# (492, 23)

# %%
djo_speed.shape
# Out:
# (100, 18)
