# %%
import pandas as pd
import numpy as np

# %%
djo = pd.read_csv('djokovic_serve_chart.csv')
#djo.drop(columns=['Unnamed: 0'], inplace=True)
djo = djo.replace('-', np.nan)

# %%
djo
# Out:
#      year          tourney round result   opponent  Unret%  <=3 W%  RiP W%  \
# 0    2021        Wimbledon    QF      L    Hurkacz    22.6    43.0    43.5
# 1    2021        Wimbledon   R16      W     Sonego    37.2    52.6    58.3
# 2    2021        Wimbledon   R32      W     Norrie    38.6    56.1    52.9
# 3    2021        Wimbledon   R64      W    Gasquet    34.7    54.7    61.3
# 4    2021        Wimbledon  R128      W  Mannarino    29.5    41.1    57.9
# ..    ...              ...   ...    ...        ...     ...     ...     ...
# 646  2000        Marseille     F      L     Rosset    19.5    28.0    54.3
# 647  2000        Davis Cup    RR      L     Hewitt    22.0    29.3    46.2
# 648  2000  Australian Open   R64      W    Kroslak    39.6    50.9    48.3
# 649  1999        Davis Cup    RR      L    Malisse    13.9    27.9    49.3
# 650  1998            Basel   R32      L     Agassi    24.5    35.8    36.8
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# 0        52.4      34.1  ...      52.4         48.7     39.3     54.5
# 1        61.5      44.0  ...      61.5         56.0     36.4     40.0
# 2        56.5      48.8  ...      56.5         54.7     59.5     41.0
# 3        72.2      45.1  ...      72.2         58.4     56.7     48.5
# 4        55.0      36.2  ...      55.0         52.2     37.1     54.5
# ..        ...       ...  ...       ...          ...      ...      ...
# 646      50.0      21.3  ...      50.0         39.7     60.0     68.4
# 647      57.5      28.4  ...      57.5         47.4     40.7     55.9
# 648      40.0      42.9  ...      40.0         50.0     50.0     66.7
# 649      52.9      21.9  ...      52.9         27.6     37.2     72.9
# 650      47.6      29.2  ...      47.6         40.3     71.4     58.8
#
#      BP Wide%  2nd: Unret%  2nd: <=3 W%  2nd: RiP W%  2ndAgg  surface
# 0        37.5          6.9         27.6         29.6     -49    grass
# 1       100.0         26.7         43.3         54.5     -30    grass
# 2         0.0         36.8         47.4         45.8     -79    grass
# 3        66.7         18.8         28.1         46.2     -79    grass
# 4       100.0         12.2         22.0         61.1       7    grass
# ..        ...          ...          ...          ...     ...      ...
# 646       NaN         14.3         28.6         58.3      22     hard
# 647       NaN         10.2         16.9         37.7     -12     hard
# 648      75.0         35.9         48.7         60.0      62     hard
# 649      70.0         14.0         22.8         42.9      22     hard
# 650      50.0         15.0         20.0         23.5      32     hard
#
# [651 rows x 23 columns]

# %%
djo.dtypes
# Out:
# year             int64
# tourney         object
# round           object
# result          object
# opponent        object
# Unret%         float64
# <=3 W%         float64
# RiP W%         float64
# RiP W%.1       float64
# SvImpact       float64
# 1st: Unret%    float64
# 1st: <=3 W%    float64
# RiP W%.2       float64
# RiP W%.3       float64
# SvImpact1st    float64
# D Wide%        float64
# A Wide%        float64
# BP Wide%       float64
# 2nd: Unret%    float64
# 2nd: <=3 W%    float64
# 2nd: RiP W%    float64
# 2ndAgg           int64
# surface         object
# dtype: object

# %%
string_cols=[ 'Unret%', '<=3 W%',
       'RiP W%', 'RiP W%.1', 'SvImpact', '1st: Unret%', '1st: <=3 W%',
       'RiP W%.2', 'RiP W%.3', 'SvImpact1st', 'D Wide%', 'A Wide%', 'BP Wide%',
       '2nd: Unret%', '2nd: <=3 W%', '2nd: RiP W%']

for col in string_cols:
    djo[col] = djo[col].str.replace('%', '')
    djo[col] = djo[col].astype('float64')
djo
# Out:
#      year          tourney round result   opponent  Unret%  <=3 W%  RiP W%  \
# 0    2021        Wimbledon    QF      L    Hurkacz    22.6    43.0    43.5
# 1    2021        Wimbledon   R16      W     Sonego    37.2    52.6    58.3
# 2    2021        Wimbledon   R32      W     Norrie    38.6    56.1    52.9
# 3    2021        Wimbledon   R64      W    Gasquet    34.7    54.7    61.3
# 4    2021        Wimbledon  R128      W  Mannarino    29.5    41.1    57.9
# ..    ...              ...   ...    ...        ...     ...     ...     ...
# 646  2000        Marseille     F      L     Rosset    19.5    28.0    54.3
# 647  2000        Davis Cup    RR      L     Hewitt    22.0    29.3    46.2
# 648  2000  Australian Open   R64      W    Kroslak    39.6    50.9    48.3
# 649  1999        Davis Cup    RR      L    Malisse    13.9    27.9    49.3
# 650  1998            Basel   R32      L     Agassi    24.5    35.8    36.8
#
#      RiP W%.1  SvImpact  ...  RiP W%.2  RiP W%.3  SvImpact1st  D Wide%  \
# 0        52.4      34.1  ...      43.5      52.4         48.7     39.3
# 1        61.5      44.0  ...      58.3      61.5         56.0     36.4
# 2        56.5      48.8  ...      52.9      56.5         54.7     59.5
# 3        72.2      45.1  ...      61.3      72.2         58.4     56.7
# 4        55.0      36.2  ...      57.9      55.0         52.2     37.1
# ..        ...       ...  ...       ...       ...          ...      ...
# 646      50.0      21.3  ...      54.3      50.0         39.7     60.0
# 647      57.5      28.4  ...      46.2      57.5         47.4     40.7
# 648      40.0      42.9  ...      48.3      40.0         50.0     50.0
# 649      52.9      21.9  ...      49.3      52.9         27.6     37.2
# 650      47.6      29.2  ...      36.8      47.6         40.3     71.4
#
#      A Wide%  BP Wide%  2nd: Unret%  2nd: <=3 W%  2nd: RiP W%  2ndAgg
# 0       54.5      37.5          6.9         27.6         29.6     -49
# 1       40.0     100.0         26.7         43.3         54.5     -30
# 2       41.0       0.0         36.8         47.4         45.8     -79
# 3       48.5      66.7         18.8         28.1         46.2     -79
# 4       54.5     100.0         12.2         22.0         61.1       7
# ..       ...       ...          ...          ...          ...     ...
# 646     68.4       NaN         14.3         28.6         58.3      22
# 647     55.9       NaN         10.2         16.9         37.7     -12
# 648     66.7      75.0         35.9         48.7         60.0      62
# 649     72.9      70.0         14.0         22.8         42.9      22
# 650     58.8      50.0         15.0         20.0         23.5      32
#
# [651 rows x 22 columns]

# %%
djo[djo.tourney.str.contains('Sydney')].head(10)
# Out:
#      year          tourney round result opponent  Unret%  <=3 W%  RiP W%  \
# 621  2002           Sydney     F      W    Chela    37.5    58.3    66.7
# 639  2000  Sydney Olympics    BR      L       Di    18.1    24.5    45.7
# 640  2000  Sydney Olympics    SF      L     Haas    20.8    26.4    35.7
#
#      RiP W%.1  SvImpact  ...  RiP W%.2  RiP W%.3  SvImpact1st  D Wide%  \
# 621      62.5      42.7  ...      66.7      62.5         53.4     55.6
# 639      66.7      22.0  ...      45.7      66.7         61.0     36.4
# 640      35.3      24.9  ...      35.7      35.3         43.1     41.7
#
#      A Wide%  BP Wide%  2nd: Unret%  2nd: <=3 W%  2nd: RiP W%  2ndAgg
# 621     60.0       NaN         26.3         52.6         71.4     -79
# 639     61.1     100.0         13.0         17.4         30.0       4
# 640     57.1      50.0         15.4         23.1         36.4      29
#
# [3 rows x 22 columns]

# %%
djo['tourney'].unique()
# Out:
# array(['Wimbledon', 'Roland Garros', 'Doha', 'Australian Open',
#        'Tour Finals', 'Basel', 'Shanghai', 'Laver Cup', 'US Open',
#        'Cincinnati', 'Halle', 'Rome', 'Madrid', 'Miami', 'Indian Wells',
#        'Dubai', 'Paris', 'Stuttgart', 'Rotterdam', 'Canada',
#        'Monte Carlo', 'Brisbane', 'Istanbul', 'Davis Cup', 'Hamburg',
#        'London Olympics', 'Stockholm', 'Masters Cup', 'Beijing Olympics',
#        'Estoril', 'Tokyo', 'Bangkok', 'Gstaad', 'Vienna', 'Munich',
#        'Marseille', 'Milan', 'Sydney', 's Hertogenbosch',
#        'Sydney Olympics'], dtype=object)

# %%
surfaces = {'Wimbledon': 'grass',
           'Roland Garros': 'clay',
           'Doha': 'hard',
           'Australian Open': 'hard',
           'Tour Finals': 'hard',
           'Basel': 'hard',
           'Shanghai': 'hard',
           'Laver Cup': 'hard',
           'US Open': 'hard',
            'Cincinnati': 'hard',
           'Halle': 'grass',
           'Rome': 'clay',
           'Madrid': 'clay',
           'Miami': 'hard',
           'Indian Wells': 'hard',
           'Dubai': 'hard',
           'Paris': 'hard',
           'Stuttgart': 'grass',
           'Rotterdam': 'hard',
           'Canada': 'hard',
           'Monte Carlo': 'clay',
           'Brisbane': 'hard',
           'Istanbul': 'hard',
           'Davis Cup': 'hard',
           'Hamburg': 'clay',
           'London Olympics': 'grass',
           'Stockholm': 'hard',
           'Masters Cup': 'hard',
           'Beijing Olympics': 'hard',
           'Estoril': 'clay',
           'Tokyo': 'hard',
           'Bangkok': 'hard',
           'Gstaad': 'clay',
           'Vienna': 'hard',
           'Munich': 'clay',
           'Marseille': 'hard',
           'Milan': 'clay',
           'Sydney': 'hard',
           'Sydney Olympics': 'hard',
           's Hertogenbosch': 'grass'}
djo['surface'] = djo['tourney'].apply(lambda x: surfaces[x])
djo
# Out:
#      year          tourney round result   opponent  Unret%  <=3 W%  RiP W%  \
# 0    2021        Wimbledon    QF      L    Hurkacz    22.6    43.0    43.5
# 1    2021        Wimbledon   R16      W     Sonego    37.2    52.6    58.3
# 2    2021        Wimbledon   R32      W     Norrie    38.6    56.1    52.9
# 3    2021        Wimbledon   R64      W    Gasquet    34.7    54.7    61.3
# 4    2021        Wimbledon  R128      W  Mannarino    29.5    41.1    57.9
# ..    ...              ...   ...    ...        ...     ...     ...     ...
# 646  2000        Marseille     F      L     Rosset    19.5    28.0    54.3
# 647  2000        Davis Cup    RR      L     Hewitt    22.0    29.3    46.2
# 648  2000  Australian Open   R64      W    Kroslak    39.6    50.9    48.3
# 649  1999        Davis Cup    RR      L    Malisse    13.9    27.9    49.3
# 650  1998            Basel   R32      L     Agassi    24.5    35.8    36.8
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# 0        52.4      34.1  ...      52.4         48.7     39.3     54.5
# 1        61.5      44.0  ...      61.5         56.0     36.4     40.0
# 2        56.5      48.8  ...      56.5         54.7     59.5     41.0
# 3        72.2      45.1  ...      72.2         58.4     56.7     48.5
# 4        55.0      36.2  ...      55.0         52.2     37.1     54.5
# ..        ...       ...  ...       ...          ...      ...      ...
# 646      50.0      21.3  ...      50.0         39.7     60.0     68.4
# 647      57.5      28.4  ...      57.5         47.4     40.7     55.9
# 648      40.0      42.9  ...      40.0         50.0     50.0     66.7
# 649      52.9      21.9  ...      52.9         27.6     37.2     72.9
# 650      47.6      29.2  ...      47.6         40.3     71.4     58.8
#
#      BP Wide%  2nd: Unret%  2nd: <=3 W%  2nd: RiP W%  2ndAgg  surface
# 0        37.5          6.9         27.6         29.6     -49    grass
# 1       100.0         26.7         43.3         54.5     -30    grass
# 2         0.0         36.8         47.4         45.8     -79    grass
# 3        66.7         18.8         28.1         46.2     -79    grass
# 4       100.0         12.2         22.0         61.1       7    grass
# ..        ...          ...          ...          ...     ...      ...
# 646       NaN         14.3         28.6         58.3      22     hard
# 647       NaN         10.2         16.9         37.7     -12     hard
# 648      75.0         35.9         48.7         60.0      62     hard
# 649      70.0         14.0         22.8         42.9      22     hard
# 650      50.0         15.0         20.0         23.5      32     hard
#
# [651 rows x 23 columns]

# %%
djo_wpct = (djo['result'] == 'W').mean()

# %%
djo.dropna()
djo.to_csv('djokovic_serve_chart.csv', index=False)

# %%
djo_speed = pd.read_csv('djokovic_serve_speed.csv')

# %%
djo_speed= djo_speed.dropna()
djo_speed
# Out:
#     year          tourney round result       opponent  avg speed  1st avg  \
# 0   2021        Wimbledon    QF      L        Hurkacz      107.0    112.7
# 1   2021        Wimbledon   R16      W         Sonego      105.4    112.5
# 2   2021        Wimbledon   R32      W         Norrie      106.8    112.5
# 3   2021        Wimbledon   R64      W        Gasquet      107.7    113.6
# 4   2021        Wimbledon  R128      W      Mannarino      106.8    111.6
# 5   2019          US Open    QF      L       Dimitrov      105.3    113.6
# 6   2019          US Open   R16      W         Goffin      108.4    113.0
# 7   2019          US Open   R32      W          Evans      106.2    113.1
# 8   2019          US Open   R64      W        Dzumhur      108.2    113.7
# 9   2019          US Open  R128      W          Nagal      105.7    112.9
# 10  2019        Wimbledon     F      L       Djokovic      109.2    116.6
# 11  2019        Wimbledon    SF      W          Nadal      109.5    115.2
# 12  2019        Wimbledon    QF      W      Nishikori      110.8    116.1
# 13  2019        Wimbledon   R16      W     Berrettini      111.0    117.0
# 14  2019        Wimbledon   R32      W        Pouille      110.3    114.9
# 15  2019        Wimbledon   R64      W         Clarke      111.2    117.7
# 16  2019        Wimbledon  R128      W         Harris      108.2    115.1
# 23  2018          US Open   R16      L        Millman      106.9    115.8
# 24  2018          US Open   R32      W        Kyrgios      109.6    116.5
# 25  2018          US Open   R64      W          Paire      107.7    114.5
# 26  2018          US Open  R128      W       Nishioka      109.8    114.9
# 27  2018        Wimbledon    QF      L       Anderson      110.3    115.0
# 28  2018        Wimbledon   R16      W      Mannarino      111.2    116.2
# 29  2018        Wimbledon   R32      W         Struff      109.5    116.4
# 30  2018        Wimbledon   R64      W          Lacko      110.3    116.0
# 31  2018        Wimbledon  R128      W        Lajovic      109.5    114.4
# 32  2017          US Open    QF      L            del      107.4    114.9
# 33  2017          US Open   R16      W  Kohlschreiber      107.0    114.2
# 34  2017          US Open   R32      W          Lopez      106.3    114.6
# 35  2017          US Open   R64      W        Youzhny      104.8    112.0
# 36  2017          US Open  R128      W         Tiafoe      107.3    116.1
# 37  2017        Wimbledon     F      W          Cilic      110.0    113.1
# 38  2017        Wimbledon    SF      W        Berdych      108.6    113.3
# 39  2017        Wimbledon    QF      W         Raonic      111.3    115.4
# 40  2017        Wimbledon   R16      W       Dimitrov      109.4    114.9
# 41  2017        Wimbledon   R32      W         Zverev      107.1    115.0
# 42  2017        Wimbledon   R64      W        Lajovic      109.3    115.6
# 43  2017        Wimbledon  R128      W     Dolgopolov      110.5    113.1
# 44  2017  Australian Open     F      W          Nadal      106.1    114.8
# 45  2017  Australian Open    SF      W       Wawrinka      106.3    115.3
# 47  2017  Australian Open   R16      W      Nishikori      110.5    116.7
# 48  2017  Australian Open   R32      W        Berdych      107.4    114.9
# 49  2017  Australian Open   R64      W          Rubin      105.8    114.2
# 50  2017  Australian Open  R128      W         Melzer      108.1    114.5
# 51  2016        Wimbledon    SF      L         Raonic      109.5    115.5
# 52  2016        Wimbledon    QF      W          Cilic      111.1    117.4
# 53  2016        Wimbledon   R16      W        Johnson      113.0    118.8
# 54  2016        Wimbledon   R32      W          Evans      111.1    116.1
# 55  2016        Wimbledon   R64      W         Willis      106.9    113.8
# 56  2016        Wimbledon  R128      W          Pella      109.8    115.6
#
#     1st stdev  1st t avg  1st wide avg  max 1st  min 1st  2nd avg  2nd stdev  \
# 0         6.5      117.4         109.1    122.0     88.0     95.6        4.8
# 1         6.5      116.5         106.4    122.0     94.0     94.3        7.0
# 2         7.6      115.6         109.0    126.0     98.0     95.4        3.5
# 3         6.2      116.6         110.8    124.0     95.0     96.7        7.3
# 4         8.0      115.4         106.1    123.0     91.0     98.9        3.4
# 5         5.2      116.2         109.3    123.0    100.0     91.9        7.1
# 6         7.0      116.6         108.8    125.0     95.0     96.9        4.3
# 7         7.4      118.6         108.3    124.0     94.0     92.4        7.4
# 8         6.2      116.3         109.9    123.0     96.0     94.0        6.2
# 9         7.0      118.3         107.8    123.0     93.0     93.0        6.5
# 10        6.3      120.4         113.2    126.0     99.0     95.8        5.2
# 11        6.6      118.8         109.9    125.0    103.0     97.2        4.5
# 12        7.5      120.0         112.3    126.0     85.0     99.4        7.3
# 13        5.9      120.0         113.7    125.0     94.0     96.8        7.3
# 14        7.1      119.4         111.4    125.0     96.0     99.6        6.6
# 15        6.2      121.5         114.6    127.0     93.0     99.2        6.7
# 16        6.8      118.7         111.6    124.0     96.0     98.8        6.2
# 23        6.4      119.2         112.9    125.0     97.0     97.3        7.5
# 24        6.7      119.4         113.1    124.0     91.0     95.6        5.9
# 25        8.0      118.6         111.7    125.0     87.0     97.0        6.6
# 26        7.2      119.7         111.7    127.0     91.0     97.7        7.3
# 27        5.6      117.9         112.1    125.0     86.0     99.5        6.2
# 28        6.7      120.2         112.0    126.0     95.0    101.0        6.3
# 29        7.4      120.5         112.5    128.0     93.0    100.8        8.9
# 30        6.8      120.1         111.8    125.0     97.0     96.7        9.4
# 31        9.1      119.3         109.2    125.0     87.0     96.4        9.9
# 32        7.2      118.0         110.3    125.0     90.0     94.4        7.8
# 33        6.6      117.9         108.8    123.0     95.0     92.3        7.3
# 34        6.0      118.3         112.1    123.0     98.0     95.9        4.6
# 35        8.3      116.5         107.6    124.0     83.0     93.3        8.1
# 36        4.8      117.8         112.8    124.0    104.0     96.1        7.0
# 37        7.6      117.6         110.4    123.0     89.0     99.3        5.9
# 38        7.9      117.8         109.4    124.0     92.0     98.1        7.4
# 39        8.6      119.3         111.9    126.0     89.0    101.7        5.1
# 40        7.4      118.6         111.9    125.0     91.0     97.2        7.5
# 41        7.6      119.8         110.2    126.0     97.0     94.6        7.1
# 42        7.0      119.4         113.1    125.0     96.0     99.3        7.7
# 43        9.1      116.8         108.8    125.0     87.0    100.9        4.2
# 44        7.4      118.2         110.0    128.0     98.0     91.2        5.6
# 45        7.3      119.0         110.8    125.0     87.0     92.1        7.4
# 47        6.4      119.8         113.3    124.0     96.0     95.6        8.4
# 48        7.3      120.0         110.3    126.0    100.0     96.2        7.1
# 49        8.6      117.7         111.6    126.0     79.0     92.6        7.1
# 50        8.4      118.5         113.1    125.0     88.0     96.4        5.9
# 51        6.2      119.1         112.5    126.0    100.0     98.9        6.8
# 52        7.9      121.8         114.3    128.0     90.0    100.3        6.7
# 53        5.4      120.6         116.4    128.0    102.0    100.7        6.4
# 54        8.7      120.2         112.5    127.0     87.0    100.7        6.3
# 55        7.9      117.9         110.6    125.0     95.0     96.0        6.3
# 56        8.6      121.0         111.2    125.0     80.0     99.6        4.7
#
#     2nd t avg  2nd wide avg  max 2nd  min 2nd surface
# 0        99.2          95.4    102.0     85.0   grass
# 1        97.5          92.8    106.0     79.0   grass
# 2        98.1          93.3    102.0     87.0   grass
# 3       100.7          93.9    111.0     81.0   grass
# 4       100.1          96.7    107.0     91.0   grass
# 5        96.8          91.5    105.0     74.0    hard
# 6       101.0          94.5    106.0     91.0    hard
# 7        96.6          92.0    104.0     81.0    hard
# 8        97.2          91.2    108.0     82.0    hard
# 9        93.6          95.4    105.0     79.0    hard
# 10       95.5          98.4    108.0     85.0   grass
# 11      100.5          95.3    108.0     86.0   grass
# 12      102.3          92.8    110.0     76.0   grass
# 13      105.0          99.5    106.0     82.0   grass
# 14      103.7          94.5    108.0     84.0   grass
# 15      101.5          97.0    109.0     86.0   grass
# 16       99.5          92.8    108.0     81.0   grass
# 23      101.3          93.7    113.0     66.0    hard
# 24       97.9          96.4    107.0     85.0    hard
# 25       99.7          90.5    112.0     79.0    hard
# 26      101.8          97.6    112.0     82.0    hard
# 27      103.2          97.2    110.0     77.0   grass
# 28      105.3          98.7    112.0     90.0   grass
# 29      105.3          99.6    116.0     77.0   grass
# 30      101.0          91.3    111.0     79.0   grass
# 31      101.3          85.0    110.0     81.0   grass
# 32       96.9          94.9    111.0     77.0    hard
# 33       95.4          89.3    107.0     79.0    hard
# 34       95.8          95.3    103.0     86.0    hard
# 35       96.6          99.5    110.0     66.0    hard
# 36      100.5          94.4    112.0     79.0    hard
# 37       99.3          93.0    111.0     88.0   grass
# 38       98.0          92.2    109.0     80.0   grass
# 39      104.3         103.0    112.0     91.0   grass
# 40      102.0          97.8    109.0     82.0   grass
# 41      100.3          96.0    113.0     82.0   grass
# 42      101.8          97.0    113.0     84.0   grass
# 43       91.0         101.5    105.0     91.0   grass
# 44       91.3          93.9    108.0     77.0    hard
# 45      102.0          92.0    105.0     79.0    hard
# 47      100.7          95.0    112.0     77.0    hard
# 48      100.6          90.0    107.0     80.0    hard
# 49       93.0          96.3    103.0     74.0    hard
# 50       99.6          96.0    107.0     78.0    hard
# 51      101.0          97.0    114.0     77.0   grass
# 52      103.3         102.0    111.0     80.0   grass
# 53      100.1         101.3    110.0     85.0   grass
# 54      101.8          99.0    111.0     87.0   grass
# 55       95.8          92.4    110.0     85.0   grass
# 56      101.0          95.6    107.0     89.0   grass

# %%
djo_speed.to_csv('djokovic_serve_speed.csv', index=False)
