# %%
import pandas as pd
import numpy as np

# %%
med = pd.read_csv('medvedev_serve_chart.csv')
med = med.replace('-', np.NaN)

# %%
med
# Out:
#      year       tourney round result    opponent  Unret%  <=3 W%  RiP W%  \
# 0    2025   Monte Carlo   R16      L          De    11.5    13.5    30.2
# 1    2025         Miami   R64      L       Munar    18.9    34.0    48.7
# 2    2025  Indian Wells    SF      L        Rune    20.0    26.7    50.0
# 3    2025  Indian Wells    QF      W        Fils    27.3    34.1    57.4
# 4    2025         Dubai    QF      L  Griekspoor    33.9    42.2    54.4
# ..    ...           ...   ...    ...         ...     ...     ...     ...
# 298  2017       Chennai    SF      W        Sela    25.0    39.6    55.7
# 299  2016    Orleans CH   R16      W      Darcis    21.1    29.8    57.5
# 300  2016       Hamburg   R16      L      Gimeno    25.8    32.8    50.5
# 301  2016     Ilkley CH   R16      L    Harrison    24.8    44.8    58.1
# 302  2016      Kazan CH    QF      W     Ivashka    34.3    44.3    60.5
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# ...

# %%
med.dtypes
# Out:
# year             int64
# tourney         object
# round           object
# result          object
# opponent        object
# Unret%         float64
# <=3 W%         float64
# RiP W%         float64
# RiP W%.1       float64
# SvImpact       float64
# 1st: Unret%    float64
# 1st: <=3 W%    float64
# RiP W%.2       float64
# RiP W%.3       float64
# SvImpact1st    float64
# D Wide%        float64
# A Wide%        float64
# BP Wide%       float64
# 2nd: Unret%    float64
# 2nd: <=3 W%    float64
# 2nd: RiP W%    float64
# 2ndAgg           int64
# surface         object
# dtype: object

# %%
med = med.dropna()

# %%
med
# Out:
#      year       tourney round result    opponent  Unret%  <=3 W%  RiP W%  \
# 0    2025   Monte Carlo   R16      L          De    11.5    13.5    30.2
# 1    2025         Miami   R64      L       Munar    18.9    34.0    48.7
# 2    2025  Indian Wells    SF      L        Rune    20.0    26.7    50.0
# 3    2025  Indian Wells    QF      W        Fils    27.3    34.1    57.4
# 4    2025         Dubai    QF      L  Griekspoor    33.9    42.2    54.4
# ..    ...           ...   ...    ...         ...     ...     ...     ...
# 298  2017       Chennai    SF      W        Sela    25.0    39.6    55.7
# 299  2016    Orleans CH   R16      W      Darcis    21.1    29.8    57.5
# 300  2016       Hamburg   R16      L      Gimeno    25.8    32.8    50.5
# 301  2016     Ilkley CH   R16      L    Harrison    24.8    44.8    58.1
# 302  2016      Kazan CH    QF      W     Ivashka    34.3    44.3    60.5
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# ...

# %%
med.to_csv('medvedev_serve_chart.csv', index=False)

# %%
med_speed = pd.read_csv('medvedev_serve_speed.csv')
med_speed
# Out:
#     year        tourney round result   opponent  avg speed  1st avg  \
# 0   2024        US Open    QF      L     Sinner      105.4    114.5
# 1   2024        US Open   R16      W     Borges      111.2    118.8
# 2   2024        US Open   R32      W    Cobolli      107.9    119.1
# 3   2024        US Open   R64      W   Marozsan      105.9    117.5
# 4   2024        US Open  R128      W    Lajovic      108.1    117.5
# ..   ...            ...   ...    ...        ...        ...      ...
# 57  2018        US Open   R64      W  Tsitsipas      104.4    116.6
# 58  2018      Wimbledon   R32      L  Mannarino      101.6    112.9
# 59  2018      Wimbledon  R128      W      Coric      102.0    115.1
# 60  2017      Wimbledon  R128      W   Wawrinka      112.3    119.5
# 61  2017  Roland Garros  R128      L      Bonzi      103.3    116.5
#
#     1st stdev  1st t avg  1st wide avg  max 1st  min 1st  2nd avg  2nd stdev  \
# ...

# %%
med_speed = med_speed.dropna()
med_speed
# Out:
#     year    tourney round result     opponent  avg speed  1st avg  1st stdev  \
# 0   2024    US Open    QF      L       Sinner      105.4    114.5        9.7
# 1   2024    US Open   R16      W       Borges      111.2    118.8        7.5
# 2   2024    US Open   R32      W      Cobolli      107.9    119.1        7.1
# 3   2024    US Open   R64      W     Marozsan      105.9    117.5        6.2
# 4   2024    US Open  R128      W      Lajovic      108.1    117.5        7.1
# 5   2024  Wimbledon    SF      L      Alcaraz      112.8    117.7        4.2
# 6   2024  Wimbledon    QF      W       Sinner      112.8    119.7        5.1
# 7   2024  Wimbledon   R16      W     Dimitrov      107.2    116.0        5.3
# 8   2024  Wimbledon   R32      W       Struff      111.2    115.7        5.8
# 9   2024  Wimbledon   R64      W       Muller      108.8    116.5        7.0
# 11  2023    US Open     F      L     Djokovic      110.4    117.5        5.5
# ...

# %%
med_speed.to_csv('medvedev_serve_speed.csv', index=False)

# %%
med.shape
# Out:
# (246, 23)

# %%
med_speed.shape
# Out:
# (56, 19)
