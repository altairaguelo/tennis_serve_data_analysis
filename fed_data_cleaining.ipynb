# %%
import pandas as pd
import numpy as np

# %%
fed = pd.read_csv('/Users/dan/Documents/GitHub/Group053_SP25/federer_serve_chart.csv')
fed.drop(columns=['Unnamed: 0'], inplace=True)
fed = fed.replace('-', np.NaN)

# %%
string_cols=[ 'Unret%', '<=3 W%',
       'RiP W%', 'RiP W%.1', 'SvImpact', '1st: Unret%', '1st: <=3 W%',
       'RiP W%.2', 'RiP W%.3', 'SvImpact1st', 'D Wide%', 'A Wide%', 'BP Wide%',
       '2nd: Unret%', '2nd: <=3 W%', '2nd: RiP W%']

for col in string_cols:
    fed[col] = fed[col].str.replace('%', '')
    fed[col] = fed[col].astype('float64')
fed
# Out:
#      year     tourney round result   opponent  Unret%  <=3 W%  RiP W%  \
# 0    2021   Wimbledon    QF      L    Hurkacz    22.6    43.0    43.5
# 1    2021   Wimbledon   R16      W     Sonego    37.2    52.6    58.3
# 2    2021   Wimbledon   R32      W     Norrie    38.6    56.1    52.9
# 3    2021   Wimbledon   R64      W    Gasquet    34.7    54.7    61.3
# 4    2021   Wimbledon  R128      W  Mannarino    29.5    41.1    57.9
# ..    ...         ...   ...    ...        ...     ...     ...     ...
# 646  2000   Marseille     F      L     Rosset    19.5    28.0    54.3
# 647  2000       Davis   Cup      L     Hewitt    22.0    29.3    46.2
# 648  2000  Australian  Open      W    Kroslak    39.6    50.9    48.3
# 649  1999       Davis   Cup      L    Malisse    13.9    27.9    49.3
# 650  1998       Basel   R32      L     Agassi    24.5    35.8    36.8
#
#      RiP W%.1  SvImpact  ...  RiP W%.2  RiP W%.3  SvImpact1st  D Wide%  \
# ...

# %%
fed.describe()
# Out:
#               year      Unret%      <=3 W%      RiP W%    RiP W%.1  \
# count   651.000000  651.000000  651.000000  651.000000  651.000000
# mean   2010.683564   33.026421   47.204916   56.842243   61.322427
# std       5.578091    8.388159    9.099048    9.043412   10.997806
# min    1998.000000    6.400000   15.600000   29.200000   32.000000
# 25%    2006.000000   27.300000   40.750000   50.000000   53.650000
# 50%    2011.000000   32.900000   47.800000   56.800000   61.100000
# 75%    2015.000000   38.650000   53.300000   62.750000   68.800000
# max    2021.000000   57.900000   73.800000   86.700000  100.000000
#
#          SvImpact  1st: Unret%  1st: <=3 W%    RiP W%.2    RiP W%.3  \
# count  651.000000   651.000000   651.000000  651.000000  651.000000
# mean    40.870200    41.962673    58.812596   56.842243   61.322427
# std      8.091658    10.476103    10.140168    9.043412   10.997806
# min     12.800000    13.100000    20.800000   29.200000   32.000000
# ...

# %%
fed[fed['tourney']=='Wimbledon']
# Out:
#      year    tourney round result    opponent  Unret%  <=3 W%  RiP W%  \
# 0    2021  Wimbledon    QF      L     Hurkacz    22.6    43.0    43.5
# 1    2021  Wimbledon   R16      W      Sonego    37.2    52.6    58.3
# 2    2021  Wimbledon   R32      W      Norrie    38.6    56.1    52.9
# 3    2021  Wimbledon   R64      W     Gasquet    34.7    54.7    61.3
# 4    2021  Wimbledon  R128      W   Mannarino    29.5    41.1    57.9
# ..    ...        ...   ...    ...         ...     ...     ...     ...
# 595  2003  Wimbledon    QF      W    Schalken    47.8    62.0    48.8
# 613  2002  Wimbledon  R128      L       Ancic    29.8    39.3    56.4
# 626  2001  Wimbledon    QF      L      Henman    34.7    48.7    47.9
# 627  2001  Wimbledon   R16      W     Sampras    49.2    58.6    45.3
# 643  2000  Wimbledon  R128      L  Kafelnikov    33.0    37.6    39.0
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# ...

# %%
fed['tourney'].unique()
# Out:
# array(['Wimbledon', 'Roland', 'Doha', 'Australian', 'Tour', 'Basel',
#        'Shanghai', 'Laver', 'US', 'Cincinnati', 'Halle', 'Rome', 'Madrid',
#        'Miami', 'Indian', 'Dubai', 'Paris', 'Stuttgart', 'Rotterdam',
#        'Canada', 'Monte', 'Brisbane', 'Istanbul', 'Davis', 'Hamburg',
#        'London', 'Stockholm', 'Masters', 'Beijing', 'Estoril', 'Tokyo',
#        'Bangkok', 'Gstaad', 'Vienna', 'Munich', 'Marseille', 'Milan',
#        'Sydney', 's'], dtype=object)

# %%
surfaces = {'Wimbledon': 'grass',
           'Roland': 'clay',
           'Doha': 'hard',
           'Australian': 'hard',
           'Tour': 'hard',
           'Basel': 'hard',
           'Shanghai': 'hard',
           'Laver': 'hard',
           'US': 'hard',
            'Cincinnati': 'hard',
           'Halle': 'grass',
           'Rome': 'clay',
           'Madrid': 'clay',
           'Miami': 'hard',
           'Indian': 'hard',
           'Dubai': 'hard',
           'Paris': 'clay',
           'Stuttgart': 'grass',
           'Rotterdam': 'hard',
           'Canada': 'hard',
           'Monte': 'clay',
           'Brisbane': 'hard',
           'Istanbul': 'hard',
           'Davis': 'hard',
           'Hamburg': 'clay',
           'London': 'grass',
           'Stockholm': 'hard',
           'Masters': 'hard',
           'Beijing': 'hard',
           'Estoril': 'clay',
           'Tokyo': 'hard',
           'Bangkok': 'hard',
           'Gstaad': 'clay',
           'Vienna': 'hard',
           'Munich': 'clay',
           'Marseille': 'hard',
           'Milan': 'clay',
           'Sydney': 'hard',
           's': 'grass'}
fed['surface'] = fed['tourney'].apply(lambda x: surfaces[x])
fed
# Out:
#      year     tourney round result   opponent  Unret%  <=3 W%  RiP W%  \
# 0    2021   Wimbledon    QF      L    Hurkacz    22.6    43.0    43.5
# 1    2021   Wimbledon   R16      W     Sonego    37.2    52.6    58.3
# 2    2021   Wimbledon   R32      W     Norrie    38.6    56.1    52.9
# 3    2021   Wimbledon   R64      W    Gasquet    34.7    54.7    61.3
# 4    2021   Wimbledon  R128      W  Mannarino    29.5    41.1    57.9
# ..    ...         ...   ...    ...        ...     ...     ...     ...
# 646  2000   Marseille     F      L     Rosset    19.5    28.0    54.3
# 647  2000       Davis   Cup      L     Hewitt    22.0    29.3    46.2
# 648  2000  Australian  Open      W    Kroslak    39.6    50.9    48.3
# 649  1999       Davis   Cup      L    Malisse    13.9    27.9    49.3
# 650  1998       Basel   R32      L     Agassi    24.5    35.8    36.8
#
#      RiP W%.1  SvImpact  ...  RiP W%.3  SvImpact1st  D Wide%  A Wide%  \
# ...

# %%
fed_wpct = (fed['result'] == 'W').mean()
